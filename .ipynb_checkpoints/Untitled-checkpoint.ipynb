# %%
import pandas as pd
import nba_api as nba
from nba_api.stats.static import teams
from nba_api.stats.static import players
from nba_api.stats.endpoints import teampgamelog

# %%
pd.DataFrame(teams.get_teams())
# Out:
#    abbreviation           city               full_name          id  \
# 0           ATL        Atlanta           Atlanta Hawks  1610612737
# 1           BOS         Boston          Boston Celtics  1610612738
# 2           CLE      Cleveland     Cleveland Cavaliers  1610612739
# 3           NOP    New Orleans    New Orleans Pelicans  1610612740
# 4           CHI        Chicago           Chicago Bulls  1610612741
# 5           DAL         Dallas        Dallas Mavericks  1610612742
# 6           DEN         Denver          Denver Nuggets  1610612743
# 7           GSW   Golden State   Golden State Warriors  1610612744
# 8           HOU        Houston         Houston Rockets  1610612745
# 9           LAC    Los Angeles    Los Angeles Clippers  1610612746
# 10          LAL    Los Angeles      Los Angeles Lakers  1610612747
# 11          MIA          Miami              Miami Heat  1610612748
# 12          MIL      Milwaukee         Milwaukee Bucks  1610612749
# ...

# %%
pd.DataFrame(players.get_players())
# Out:
#      first_name            full_name       id     last_name
# 0          Alaa       Alaa Abdelnaby    76001     Abdelnaby
# 1          Zaid      Zaid Abdul-Aziz    76002    Abdul-Aziz
# 2        Kareem  Kareem Abdul-Jabbar    76003  Abdul-Jabbar
# 3       Mahmoud   Mahmoud Abdul-Rauf       51    Abdul-Rauf
# 4         Tariq    Tariq Abdul-Wahad     1505   Abdul-Wahad
# 5       Shareef  Shareef Abdur-Rahim      949   Abdur-Rahim
# 6           Tom        Tom Abernethy    76005     Abernethy
# 7        Forest          Forest Able    76006          Able
# 8          John       John Abramovic    76007     Abramovic
# 9          Alex         Alex Abrines   203518       Abrines
# 10         Alex           Alex Acker   101165         Acker
# 11       Donald      Donald Ackerman    76008      Ackerman
# 12         Mark           Mark Acres    76009         Acres
# 13      Charles        Charles Acton    76010         Acton
# 14       Quincy           Quincy Acy   203112           Acy
# ...
